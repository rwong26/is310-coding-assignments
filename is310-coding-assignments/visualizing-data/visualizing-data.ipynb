# %%
import subprocess
import sys

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

install('Altair')
import pandas as pd
import altair as alt

film_scripts = pd.read_csv('cleaned_pudding_data.csv')
film_scripts
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 11>()
#       8 import pandas as pd
#       9 import altair as alt
# ---> 11 film_scripts = pd.read_csv('cleaned_pudding_data.csv')
#      12 film_scripts
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cleaned_pudding_data.csv'

# %%
character_list_df = pd.read_csv('character_list5.csv', encoding='ISO-8859-1')
character_mapping_df = pd.read_csv('character_mapping.csv', encoding='ISO-8859-1')
metaddata_df = pd.read_csv('meta_data7.csv', encoding='ISO-8859-1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 character_list_df = pd.read_csv('character_list5.csv', encoding='ISO-8859-1')
#       2 character_mapping_df = pd.read_csv('character_mapping.csv', encoding='ISO-8859-1')
#       3 metaddata_df = pd.read_csv('meta_data7.csv', encoding='ISO-8859-1')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:934, in TextFileReader.__init__(self, f, engine, **kwds)
#     931     self.options["has_index_names"] = kwds["has_index_names"]
#     933 self.handles: IOHandles | None = None
# --> 934 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:1218, in TextFileReader._make_engine(self, f, engine)
#    1214     mode = "rb"
#    1215 # error: No overload variant of "get_handle" matches argument types
#    1216 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218 self.handles = get_handle(  # type: ignore[call-overload]
#    1219     f,
#    1220     mode,
#    1221     encoding=self.options.get("encoding", None),
#    1222     compression=self.options.get("compression", None),
#    1223     memory_map=self.options.get("memory_map", False),
#    1224     is_text=is_text,
#    1225     errors=self.options.get("encoding_errors", "strict"),
#    1226     storage_options=self.options.get("storage_options", None),
#    1227 )
#    1228 assert self.handles is not None
#    1229 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'character_list5.csv'

# %%
film_scripts.columns
# Out:
# Index(['imdb_id', 'script_id', 'title', 'year', 'gross (inflation-adjusted)',
#        'link'],
#       dtype='object')

# %%
import altair as alt

# %%
dialogue_df = pd.merge(character_list_df, metaddata_df, on='script_id', how="inner")
dialogue_df
# Out:
#        script_id imdb_character_name  words gender   age    imdb_id  \
# 0            280               betty    311      f  35.0  tt0112579
# 1            280     carolyn johnson    873      f   NaN  tt0112579
# 2            280             eleanor    138      f   NaN  tt0112579
# 3            280     francesca johns   2251      f  46.0  tt0112579
# 4            280               madge    190      f  46.0  tt0112579
# ...          ...                 ...    ...    ...   ...        ...
# 23043       9254             lumiere   1063      m  56.0  tt0101414
# 23044       9254             maurice   1107      m  71.0  tt0101414
# 23045       9254     monsieur d'arqu    114      m  58.0  tt0101414
# 23046       9254          mrs. potts    564      f  66.0  tt0101414
# 23047       9254            wardrobe    121      f  54.0  tt0101414
#
#                                title  year  gross  \
# 0      The Bridges of Madison County  1995  142.0
# 1      The Bridges of Madison County  1995  142.0
# 2      The Bridges of Madison County  1995  142.0
# 3      The Bridges of Madison County  1995  142.0
# 4      The Bridges of Madison County  1995  142.0
# ...                              ...   ...    ...
# 23043           Beauty and the Beast  1991  452.0
# 23044           Beauty and the Beast  1991  452.0
# 23045           Beauty and the Beast  1991  452.0
# 23046           Beauty and the Beast  1991  452.0
# 23047           Beauty and the Beast  1991  452.0
#
#                                               lines_data
# 0      4332023434343443203433434334433434343434434344...
# 1      4332023434343443203433434334433434343434434344...
# 2      4332023434343443203433434334433434343434434344...
# 3      4332023434343443203433434334433434343434434344...
# 4      4332023434343443203433434334433434343434434344...
# ...                                                  ...
# 23043  3245753334377767774433634446467677732244465553...
# 23044  3245753334377767774433634446467677732244465553...
# 23045  3245753334377767774433634446467677732244465553...
# 23046  3245753334377767774433634446467677732244465553...
# 23047  3245753334377767774433634446467677732244465553...
#
# [23048 rows x 10 columns]

# %%
extended_dialogue_df = pd.merge(character_list_df, film_scripts, on='script_id', how="inner")
extended_dialogue_df
# Out:
#       script_id imdb_character_name  words gender   age    imdb_id  \
# 0           280               betty    311      f  35.0  tt0112579
# 1           280     carolyn johnson    873      f   NaN  tt0112579
# 2           280             eleanor    138      f   NaN  tt0112579
# 3           280     francesca johns   2251      f  46.0  tt0112579
# 4           280               madge    190      f  46.0  tt0112579
# ...         ...                 ...    ...    ...   ...        ...
# 1402       5254      herr falkstein    158      m  69.0  tt0072431
# 1403       5254                igor   1072      m  40.0  tt0072431
# 1404       5254                inga    808      f  27.0  tt0072431
# 1405       5254     medical student    199      m   NaN  tt0072431
# 1406       5254         the monster    586      m  39.0  tt0072431
#
#                               title  year  gross (inflation-adjusted)  \
# 0     The Bridges of Madison County  1995                       142.0
# 1     The Bridges of Madison County  1995                       142.0
# 2     The Bridges of Madison County  1995                       142.0
# 3     The Bridges of Madison County  1995                       142.0
# 4     The Bridges of Madison County  1995                       142.0
# ...                             ...   ...                         ...
# 1402             Young Frankenstein  1974                       401.0
# 1403             Young Frankenstein  1974                       401.0
# 1404             Young Frankenstein  1974                       401.0
# 1405             Young Frankenstein  1974                       401.0
# 1406             Young Frankenstein  1974                       401.0
#
#                                              link
# 0      http://www.awesomefilm.com/script/bomc.txt
# 1      http://www.awesomefilm.com/script/bomc.txt
# 2      http://www.awesomefilm.com/script/bomc.txt
# 3      http://www.awesomefilm.com/script/bomc.txt
# 4      http://www.awesomefilm.com/script/bomc.txt
# ...                                           ...
# 1402  http://www.horrorlair.com/scripts/young.txt
# 1403  http://www.horrorlair.com/scripts/young.txt
# 1404  http://www.horrorlair.com/scripts/young.txt
# 1405  http://www.horrorlair.com/scripts/young.txt
# 1406  http://www.horrorlair.com/scripts/young.txt
#
# [1407 rows x 10 columns]

# %%
grouped_ex_dialogue_df = extended_dialogue_df.groupby(['year', 'gender'])['words'].sum().reset_index()
grouped_ex_dialogue_df['date'] = grouped_ex_dialogue_df['year'].astype(str) + '-01-01'
grouped_ex_dialogue_df['date'] = pd.to_datetime(grouped_ex_dialogue_df['date'])
alt.Chart(grouped_ex_dialogue_df).mark_line().encode(
    x='date:T',
    y='words',
    color='gender'
).properties(
    title='Dialogue Over Time Colored By Gender (film_scripts)'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <h2> How could we tell if the amount of dialogue was increasing over time in movies? How might this influence the assessment about the breakdown of gender dialogue?

# %% [markdown]
# The graph above shows that movies have more talking in them now than they did before, starting in the 1990s. Also, male characters talk more than female characters over time.

# %% [markdown]
# <h2> How could test if there was any relationship between the film’s gross value and the amount of dialogue in the film?

# %%
merge_df = pd.merge(dialogue_df, film_scripts[['gross (inflation-adjusted)']], left_on='gross', right_on='gross (inflation-adjusted)', how='inner')
merge_df
# Out:
#         script_id imdb_character_name  words gender   age    imdb_id  \
# 0             280               betty    311      f  35.0  tt0112579
# 1             280     carolyn johnson    873      f   NaN  tt0112579
# 2             280             eleanor    138      f   NaN  tt0112579
# 3             280     francesca johns   2251      f  46.0  tt0112579
# 4             280               madge    190      f  46.0  tt0112579
# ...           ...                 ...    ...    ...   ...        ...
# 163621       5254      herr falkstein    158      m  69.0  tt0072431
# 163622       5254                igor   1072      m  40.0  tt0072431
# 163623       5254                inga    808      f  27.0  tt0072431
# 163624       5254     medical student    199      m   NaN  tt0072431
# 163625       5254         the monster    586      m  39.0  tt0072431
#
#                                 title  year  gross  \
# 0       The Bridges of Madison County  1995  142.0
# 1       The Bridges of Madison County  1995  142.0
# 2       The Bridges of Madison County  1995  142.0
# 3       The Bridges of Madison County  1995  142.0
# 4       The Bridges of Madison County  1995  142.0
# ...                               ...   ...    ...
# 163621             Young Frankenstein  1974  401.0
# 163622             Young Frankenstein  1974  401.0
# 163623             Young Frankenstein  1974  401.0
# 163624             Young Frankenstein  1974  401.0
# 163625             Young Frankenstein  1974  401.0
#
#                                                lines_data  \
# 0       4332023434343443203433434334433434343434434344...
# 1       4332023434343443203433434334433434343434434344...
# 2       4332023434343443203433434334433434343434434344...
# 3       4332023434343443203433434334433434343434434344...
# 4       4332023434343443203433434334433434343434434344...
# ...                                                   ...
# 163621  7777721374572264357636646755234465233200247532...
# 163622  7777721374572264357636646755234465233200247532...
# 163623  7777721374572264357636646755234465233200247532...
# 163624  7777721374572264357636646755234465233200247532...
# 163625  7777721374572264357636646755234465233200247532...
#
#         gross (inflation-adjusted)
# 0                            142.0
# 1                            142.0
# 2                            142.0
# 3                            142.0
# 4                            142.0
# ...                            ...
# 163621                       401.0
# 163622                       401.0
# 163623                       401.0
# 163624                       401.0
# 163625                       401.0
#
# [163626 rows x 11 columns]

# %%
grouped_merge_df = merge_df.groupby(['gross (inflation-adjusted)'])['words'].sum().reset_index()
alt.Chart(grouped_merge_df).mark_line().encode(
    x='gross (inflation-adjusted):Q',
    y='words',
).properties(
    title='Dialogue Over Gross Value (film_scripts)'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Gross value is lower when there were more dialogues in the film.
